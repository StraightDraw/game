# %% [markdown]
# # Exercises
#
# :::{sidebar} Discovering Game Theory
# This course uses an **online textbook**: [Game Theory, a Discovery Approach](https://nordstrommath.com/IntroGameTheory2e/intro_game_theory.html), by Jennifer Nordstrom.
# :::
#
# The following problems will be useful practice for the graphing method of solution.

# %%
## Do not change this cell, only execute it. 
## This cell initializes Python so that pandas, numpy and scipy packages are ready to use.

import datascience
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import numpy as np
import scipy as sp
import math
import scipy.stats as stats
from fractions import Fraction

# %% [markdown]
# :::{admonition} Exercise 1
#
# Solve the game using the graphing method backstopped by oddments.
#
# $$\begin{array}{cc}&\textbf{Rose}\\\textbf{Colin}& \begin{array}{r|cccc} & A & B & C & D \\ \hline A & 2 & 6 & 1 & 4 \\ B & 5 & 0 & 7 & 3\end{array} \end{array}$$
#
# :::
#
# :::{dropdown} Solution
#
# Coming soon ...
# :::

# %% [markdown]
# :::{admonition} Exercise 2
#
# Solve the game using the graphing method backstopped by oddments.
#
# $$\begin{array}{cc}&\textbf{Rose}\\\textbf{Colin}& \begin{array}{r|cc} & A & B\\ \hline A & 1 & 8 \\ B & 3 & 2 \\ C & 7 & 0 \\ D & 4 & 5 \end{array} \end{array}$$
#
# :::
#
# :::{dropdown} Solution
#
# Coming soon ...
# :::

# %% [markdown]
# :::{admonition} Exercise 3
#
# Solve the game using the graphing method backstopped by oddments.
#
# $$\begin{array}{cc}&\textbf{Rose}\\\textbf{Colin}& \begin{array}{r|ccccc} & A & B & C & D & E\\ \hline A & 10 & 2 & 5 & 8 & 3 \\ B &
# 1 & 9 & 6 & 2 & 7 \end{array} \end{array}$$
#
# :::
#
# :::{dropdown} Solution
#
# Coming soon ...
# :::

# %% [markdown]
# :::{admonition} Exercise 4
#
# Solve the game using the graphing method backstopped by oddments.
#
# $$\begin{array}{cc}&\textbf{Rose}\\\textbf{Colin}& \begin{array}{r|rr} & A & B\\ \hline A & -2 & 4 \\ B & 3 & -1 \\ C & 0 & 2 \end{array} \end{array}$$
#
# :::
#
# :::{dropdown} Solution
#
# Coming soon ...
# :::

# %% [markdown]
# :::{admonition} Exercise 5
#
# Solve the game using the graphing method backstopped by oddments.
#
# $$\begin{array}{cc}&\textbf{Rose}\\\textbf{Colin}& \begin{array}{r|cccc} & A & B\\ \hline A & 4 & 1 & 8 \\ B & 2 & 5 & 0\end{array} \end{array}$$
#
# :::
#
# :::{dropdown} Solution
#
# Coming soon ...
# :::
