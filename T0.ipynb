# %% [markdown]
# # Tools of Game Theory

# %% [markdown]
# As we use Python and the tools in our UNG datahub, you will find several reference pages useful:
#
# - Dollar Sign Mathematics
# - Graphing
# - Game Solver Code
