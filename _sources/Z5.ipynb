# %% [markdown]
# # Expected Value
#
# :::{sidebar} Discovering Game Theory
# This course uses an **online textbook**: [Game Theory, a Discovery Approach](https://nordstrommath.com/IntroGameTheory2e/intro_game_theory.html), by Jennifer Nordstrom.
# :::

# %% [markdown]
# In probability theory, we find the general formula for **expected value**. Consider a numeric data set $X$ of sample size $n$ with outcomes $X=\left\{x_1, x_2, \dots , x_n\right\}$ and associated probabilities of $\left\{p(x_1), p(x_2), \dots , p(x_n)\right\}$. A t-chart often helps to visualize the scenario as is shown in the example below:
#
# $$\begin{array}{r|c}x&p(x)\\ \hline 2&\frac{1}{5}\\0&\frac{1}{7}\\-1&\frac{1}{4} \\ \vdots&\vdots \\3&\frac{1}{2}  \end{array}$$

# %% [markdown]
# **Expected Value**
# : Given a set $X$ of $n\in\mathbb{N}$ outcomes and $n$ associate probabilities, the expected value of $X$ is given as follows:
#
# $$E(X) =x_1p(x_1)+x_1p(x_1)+\dots+x_np(x_n)$$
#
# Using summation notation, we see the familiar formula:
#
# $$E(X) =\sum_{i=1}^{n}x_ip(x_i)$$
#
# which is often written without the limits included:
#
# $$E(X) =\sum x_ip(x_i)$$
