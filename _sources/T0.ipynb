# %% [markdown]
# # Tools of Game Theory

# %% [markdown]
# The first helpful tool we will provide here is a glossary of terms.
#
# - Glossary

# %% [markdown]
# As we use Python and the tools in the UNG datahub, several reference pages will prove useful:
#
# - Dollar Sign Mathematics and Equations
# - Graphing
#    - Graphing window and $xy$-axes
#    - Horizontal and Vertical Lines
#    - Line through Two Points
#    - Polygons
# - Game Solver Code
