# %% [markdown]
# # Dollar Sign Mathematics

# %% [markdown]
# The actual name of the mathematical equation editor is $\LaTeX$ which, without the graphics, is simply the word **latex** (pronounced La-Tek). The **LaTeX** equation editor is a markdown language that  mathematicians use to produce publication quality graphics for mathematics expressions, equations and symbols.
#
# The modern generation often calls it **Dollar Sign Mathematics** because, in a string of text, the in-line equations are set off by an opening and closing \$.

# %% [markdown]
# ## Polynomials and Subscripts
#
# We use the carat symbol ^ for exponents and the underscore _ for subscripts.
#
# ### Exponents
#
# The text
#
# <center><b>7x^3-2x^2-5x+1</b></center>
#
# will display as
#
# $$7x^3-2x^2-5x+1$$

# %% [markdown]
# ### Subscripts
#
# The following text
#
# <center><b>x_1 = 5</center></b>
#
# will displas as
#
# $$x_1 = 5$$

# %% [markdown]
# ## Gathering Multiple Equations
#
# We have the **align** environment for multiple equations that we would like to see centered and aligned. The double slash ends a line while the ampersand symbol forces the alignment at that spot. The text below will work in LaTeX, but we must end each equation line with a double backslash:
#
# \begin{align}
#
#   E(Rose A) &= 5x + 2y
#
#   E(Rose B) &= 2x - 42y
#
# \end{align}
#
# The display looks as follows:
#
# $$\begin{align}
#   E(Rose A) &= 5x + 2y \\
#   E(Rose B) &= 2x - 42y
# \end{align}$$

# %% [markdown]
# ## Text in Equations
#
# When we want to create the expected value of "Rose Strategy A", the standard LaTeX displays all characters as variables. The code:
#
# <center><b>E(Rose A)</b></center>
#
# displays as
#
# $$E(Rose A)$$
#
# As you can see if you look closely, the italicized font used for variables looks awkward when used for a word. However, we can use the \text{} command to print text inside the equation. The results of
#
# <center><b>E(\text{Rose A})</b></center>
#
# is shown below:
#
# $$E(\text{Rose A})$$

# %% [markdown]
# ## Vectors
#
# The code to create the symbol for a vector is straightforward:
#
# <center><b>\vec{r}</b></center>
#
# displays as
#
# $$\vec{r}$$

# %% [markdown]
# For the values in the matrix and brackets to enclose the matrix, we must work a bit harder. To create a column vector, we create an $n\times 1$ matrix with a double backslash indicating the end of row in the matrix:
#
#   \begin{array}{r}
#
#   1
#
#   2
#
#   -3
#
#   \end{array}
#
# which displays as:
#
# $$\vec{r} = \begin{array}{r}1\\2\\-3\end{array}$$

# %% [markdown]
# We can add brackets using the following enclosures:
#
# \left[
#
# and
#
# \right]
#
# which displays as follows:
#
# $$\vec{r} = \left[\begin{array}{r}1\\2\\-3\end{array}\right]$$
